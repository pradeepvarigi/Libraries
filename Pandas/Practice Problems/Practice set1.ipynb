# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# 1.Write a Pandas program to read a csv file from a specified source and print the first 5 rows

# %%
df.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# 2.Write a Pandas program to read a dataset from diamonds DataFrame and modify the default columns values and print the first 6 rows

# %%
user_cols=['carat','cut','x','y','z']
df[user_cols].head(6)
# Out:
#    carat        cut     x     y     z
# 0   0.23      Ideal  3.95  3.98  2.43
# 1   0.21    Premium  3.89  3.84  2.31
# 2   0.23       Good  4.05  4.07  2.31
# 3   0.29    Premium  4.20  4.23  2.63
# 4   0.31       Good  4.34  4.35  2.75
# 5   0.24  Very Good  3.94  3.96  2.48

# %% [markdown]
# 3.Write a Pandas program to select a series from diamonds DataFrame. Print the content of the series.

# %%
df['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %% [markdown]
# 4.Write a Pandas program to create a new 'Quality ?color' Series (use bracket notation to define the Series name) of the diamonds DataFrame.

# %%
df['Quality-Color']=df.cut+','+df.color
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-Color
# 0           Ideal,E
# 1         Premium,E
# 2            Good,E
# 3         Premium,I
# 4            Good,J
# ...             ...
# 53935       Ideal,D
# 53936        Good,D
# 53937   Very Good,D
# 53938     Premium,H
# 53939       Ideal,D
#
# [53940 rows x 11 columns]

# %% [markdown]
# 5.Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   carat          53940 non-null  float64
#  1   cut            53940 non-null  object
#  2   color          53940 non-null  object
#  3   clarity        53940 non-null  object
#  4   depth          53940 non-null  float64
#  5   table          53940 non-null  float64
#  6   price          53940 non-null  int64
#  7   x              53940 non-null  float64
#  8   y              53940 non-null  float64
#  9   z              53940 non-null  float64
#  10  Quality-Color  53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.dtypes
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# Quality-Color     object
# dtype: object

# %% [markdown]
# 6.Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe

# %%
df.describe(include='object')
# Out:
#           cut  color clarity Quality-Color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1       Ideal,G
# freq    21551  11292   13065          4884

# %% [markdown]
# 7.Write a Pandas program to rename two of the columns of the diamonds Dataframe

# %%
df.rename(columns={'color':'Diamond-Color','clarity':'Diamond-Calarty'}).head()
# Out:
#    carat      cut Diamond-Color Diamond-Calarty  depth  table  price     x  \
# 0   0.23    Ideal             E             SI2   61.5   55.0    326  3.95
# 1   0.21  Premium             E             SI1   59.8   61.0    326  3.89
# 2   0.23     Good             E             VS1   56.9   65.0    327  4.05
# 3   0.29  Premium             I             VS2   62.4   58.0    334  4.20
# 4   0.31     Good             J             SI2   63.3   58.0    335  4.34
#
#       y     z Quality-Color
# 0  3.98  2.43       Ideal,E
# 1  3.84  2.31     Premium,E
# 2  4.07  2.31        Good,E
# 3  4.23  2.63     Premium,I
# 4  4.35  2.75        Good,J

# %%
df.dtypes
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# Quality-Color     object
# dtype: object

# %%
#df_rc=['new-carat','new-cut','new-color','new-clarity','new-depth','new-table','new-price','new-x','new-y','new-z','n-Quality-Color']
#df.columns=df_rc
#df.head()

# %% [markdown]
# 9.Write a Pandas program to remove the second column of the diamonds Dataframe

# %%
df.drop('cut',axis=1)
# Out:
#        carat color clarity  depth  table  price     x     y     z  \
# 0       0.23     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-Color
# 0           Ideal,E
# 1         Premium,E
# 2            Good,E
# 3         Premium,I
# 4            Good,J
# ...             ...
# 53935       Ideal,D
# 53936        Good,D
# 53937   Very Good,D
# 53938     Premium,H
# 53939       Ideal,D
#
# [53940 rows x 10 columns]

# %% [markdown]
# 10.Write a Pandas program to remove multiple columns at once of the diamonds Dataframe

# %%
df.drop(['carat','color','depth'],axis=1)
# Out:
#              cut clarity  table  price     x     y     z Quality-Color
# 0          Ideal     SI2   55.0    326  3.95  3.98  2.43       Ideal,E
# 1        Premium     SI1   61.0    326  3.89  3.84  2.31     Premium,E
# 2           Good     VS1   65.0    327  4.05  4.07  2.31        Good,E
# 3        Premium     VS2   58.0    334  4.20  4.23  2.63     Premium,I
# 4           Good     SI2   58.0    335  4.34  4.35  2.75        Good,J
# ...          ...     ...    ...    ...   ...   ...   ...           ...
# 53935      Ideal     SI1   57.0   2757  5.75  5.76  3.50       Ideal,D
# 53936       Good     SI1   55.0   2757  5.69  5.75  3.61        Good,D
# 53937  Very Good     SI1   60.0   2757  5.66  5.68  3.56   Very Good,D
# 53938    Premium     SI2   58.0   2757  6.15  6.12  3.74     Premium,H
# 53939      Ideal     SI2   55.0   2757  5.83  5.87  3.64       Ideal,D
#
# [53940 rows x 8 columns]

# %% [markdown]
# 11.Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe

# %%
df.drop([0,1,2],axis=0)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-Color
# 3         Premium,I
# 4            Good,J
# 5       Very Good,J
# 6       Very Good,I
# 7       Very Good,H
# ...             ...
# 53935       Ideal,D
# 53936        Good,D
# 53937   Very Good,D
# 53938     Premium,H
# 53939       Ideal,D
#
# [53937 rows x 11 columns]

# %% [markdown]
# 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
df.cut.sort_values(ascending=True)
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %% [markdown]
# 13. Write a Pandas program to sort the 'price' Series in descending order (returns a Series) of diamonds Dataframe.

# %%
df.price.sort_values(ascending=False)
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 4          335
# 3          334
# 2          327
# 1          326
# 0          326
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# 14.Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
df.sort_values('carat').head()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 31593    0.2  Premium     E     VS2   61.1   59.0    367  3.81  3.78  2.32
# 31597    0.2    Ideal     D     VS2   61.5   57.0    367  3.81  3.77  2.33
# 31596    0.2  Premium     F     VS2   62.6   59.0    367  3.73  3.71  2.33
# 31595    0.2    Ideal     E     VS2   59.7   55.0    367  3.86  3.84  2.30
# 31594    0.2  Premium     E     VS2   59.7   62.0    367  3.84  3.80  2.28
#
#       Quality-Color
# 31593     Premium,E
# 31597       Ideal,D
# 31596     Premium,F
# 31595       Ideal,E
# 31594     Premium,E

# %%
df.sort_values('carat',ascending=False).head()
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z  \
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
#
#       Quality-Color
# 27415        Fair,J
# 27630        Fair,J
# 27130        Fair,H
# 25999     Premium,J
# 25998     Premium,I

# %% [markdown]
# 15.Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
den=[]
for w in df.carat:
    if w >0.3:
        den.append(True)
    else:
        den.append(False)
pd.Series(den)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Length: 53940, dtype: bool

# %%
df['w>3']=den
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   Quality-Color    w>3
# 0       Ideal,E  False
# 1     Premium,E  False
# 2        Good,E  False
# 3     Premium,I  False
# 4        Good,J   True

# %% [markdown]
# 17.Write a Pandas program to find the details of the diamonds where length>5, width>5.

# %%
re=df.rename(columns={'x':'Length','y':'width','z':'depth'})
re
# Out:
#        carat        cut color clarity  depth  table  price  Length  width  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       0.21    Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       0.23       Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       0.29    Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       0.31       Good     J     SI2   63.3   58.0    335    4.34   4.35
# ...      ...        ...   ...     ...    ...    ...    ...     ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757    5.75   5.76
# 53936   0.72       Good     D     SI1   63.1   55.0   2757    5.69   5.75
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757    5.66   5.68
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757    6.15   6.12
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757    5.83   5.87
#
#        depth Quality-Color    w>3
# 0       2.43       Ideal,E  False
# 1       2.31     Premium,E  False
# 2       2.31        Good,E  False
# 3       2.63     Premium,I  False
# 4       2.75        Good,J   True
# ...      ...           ...    ...
# 53935   3.50       Ideal,D   True
# 53936   3.61        Good,D   True
# 53937   3.56   Very Good,D   True
# 53938   3.74     Premium,H   True
# 53939   3.64       Ideal,D   True
#
# [53940 rows x 12 columns]

# %%
re[(re.Length>5)&(re.width>5)].head()
# Out:
#     carat        cut color clarity  depth  table  price  Length  width  depth  \
# 90   0.70      Ideal     E     SI1   62.5   57.0   2757    5.70   5.72   3.57
# 91   0.86       Fair     E     SI2   55.1   69.0   2757    6.45   6.33   3.52
# 92   0.70      Ideal     G     VS2   61.6   56.0   2757    5.70   5.67   3.50
# 93   0.71  Very Good     E     VS2   62.4   57.0   2759    5.68   5.73   3.56
# 94   0.78  Very Good     G     SI2   63.8   56.0   2759    5.81   5.85   3.72
#
#    Quality-Color   w>3
# 90       Ideal,E  True
# 91        Fair,E  True
# 92       Ideal,G  True
# 93   Very Good,E  True
# 94   Very Good,G  True

# %% [markdown]
# 18.Write a Pandas program to find the diamonds that are either Premium or Ideal

# %%
df[(df.cut=='Premium')|(df.cut=='Ideal')]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Quality-Color    w>3
# 0           Ideal,E  False
# 1         Premium,E  False
# 3         Premium,I  False
# 11          Ideal,J  False
# 12        Premium,F  False
# ...             ...    ...
# 53931     Premium,F   True
# 53934     Premium,D   True
# 53935       Ideal,D   True
# 53938     Premium,H   True
# 53939       Ideal,D   True
#
# [35342 rows x 12 columns]

# %% [markdown]
# 19. Write a Pandas program to find the diamonds that are with a Fair or Good or Premium

# %%
#sol1
df[(df.cut=='Fair')|(df.cut=='Good')|(df.cut=='Premium')]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 8       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53936   0.72     Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
#       Quality-Color    w>3
# 1         Premium,E  False
# 2            Good,E  False
# 3         Premium,I  False
# 4            Good,J   True
# 8            Fair,E  False
# ...             ...    ...
# 53930     Premium,E   True
# 53931     Premium,F   True
# 53934     Premium,D   True
# 53936        Good,D   True
# 53938     Premium,H   True
#
# [20307 rows x 12 columns]

# %%
#sol2
df[df.cut.isin(['Premium','Good','Fair'])]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 8       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53936   0.72     Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
#       Quality-Color    w>3
# 1         Premium,E  False
# 2            Good,E  False
# 3         Premium,I  False
# 4            Good,J   True
# 8            Fair,E  False
# ...             ...    ...
# 53930     Premium,E   True
# 53931     Premium,F   True
# 53934     Premium,D   True
# 53936        Good,D   True
# 53938     Premium,H   True
#
# [20307 rows x 12 columns]

# %% [markdown]
# 20. Write a Pandas program to display all column labels of diamonds DataFrame.

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'Quality-Color', 'w>3'],
#       dtype='object')

# %% [markdown]
# 21.Write a Pandas program to read only a subset of 3 rows from diamonds DataFrame

# %%
df[0:3]
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
#
#   Quality-Color    w>3
# 0       Ideal,E  False
# 1     Premium,E  False
# 2        Good,E  False

# %%
df2=pd.read_csv('http://bit.ly/uforeports',nrows=3)
df2
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# 22. Write a Pandas program to iterate through diamonds DataFrame.

# %%
#for index, row in df.iterrows():
#    print(index,row.carat,row.cut,row.price)

# %% [markdown]
# 23. Write a Pandas program to drop all non-numeric columns from diamonds DataFrame

# %%
#df.drop()

# %% [markdown]
# 24. Write a Pandas program to include only numeric columns in the diamonds DataFrame

# %%
a=df.select_dtypes(include=[np.number]).dtypes
a
# Out:
# carat    float64
# depth    float64
# table    float64
# price      int64
# x        float64
# y        float64
# z        float64
# dtype: object

# %% [markdown]
# 25.Write a Pandas program to pass a list of data types to only describe certain types of diamonds DataFrame

# %%
df.describe(include=['object','float64'])
# Out:
#                carat    cut  color clarity         depth         table  \
# count   53940.000000  53940  53940   53940  53940.000000  53940.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  21551  11292   13065           NaN           NaN
# mean        0.797940    NaN    NaN     NaN     61.749405     57.457184
# std         0.474011    NaN    NaN     NaN      1.432621      2.234491
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         5.010000    NaN    NaN     NaN     79.000000     95.000000
#
#                    x             y             z Quality-Color
# count   53940.000000  53940.000000  53940.000000         53940
# unique           NaN           NaN           NaN            35
# top              NaN           NaN           NaN       Ideal,G
# freq             NaN           NaN           NaN          4884
# mean        5.731157      5.734526      3.538734           NaN
# std         1.121761      1.142135      0.705699           NaN
# min         0.000000      0.000000      0.000000           NaN
# 25%         4.710000      4.720000      2.910000           NaN
# 50%         5.700000      5.710000      3.530000           NaN
# 75%         6.540000      6.540000      4.040000           NaN
# max        10.740000     58.900000     31.800000           NaN

# %% [markdown]
# 26.Write a Pandas program to calculate the mean of each numeric column of diamonds DataFrame.

# %%
df.mean(axis=1).head()
# Out:
# 0    56.63625
# 1    57.13125
# 2    57.44500
# 3    58.21875
# 4    58.63125
# dtype: float64

# %% [markdown]
# 27.Write a Pandas program to calculate the mean of each row of diamonds DataFrame.

# %%
df.mean(axis=0)
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# w>3         0.922080
# dtype: float64

# %% [markdown]
# 28.Write a Pandas program to calculate the mean of price for each cut of diamonds DataFrame.

# %%
df.groupby('cut').price.mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# 29. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
df.groupby("cut").price.agg(['count','min','max'])
# Out:
#            count  min    max
# cut
# Fair        1610  337  18574
# Good        4906  327  18788
# Ideal      21551  326  18806
# Premium    13791  326  18823
# Very Good  12082  336  18818

# %% [markdown]
# 30. Write a Pandas program to create a side-by-side bar plot of the diamonds DataFrame.

# %%
df.groupby('cut').mean().plot(kind='bar')

# %% [markdown]
# 31. Write a Pandas program to count how many times each value in cut series of diamonds DataFrame occurs

# %%
#df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# 32. Write a Pandas program to display percentages of each value of cut series occurs in diamonds DataFrame.

# %%
df.cut.value_counts(normalize=True)
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %% [markdown]
# 33.Write a Pandas program to display the unique values in cut series of diamonds DataFrame.

# %%
df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# 34. Write a Pandas program to count the number of unique values in cut series of diamonds DataFrame.

# %%
df.cut.nunique()
# Out:
# 5

# %% [markdown]
# 35. Write a Pandas program to compute a cross-tabulation of two Series in diamonds DataFrame.

# %%
pd.crosstab(df.cut,df.price).head()
# Out:
# price      326    327    334    335    336    337    338    339    340    \
# cut
# Fair           0      0      0      0      0      1      0      0      0
# Good           0      1      0      1      0      0      0      1      0
# Ideal          1      0      0      0      0      0      0      0      1
# Premium        1      0      1      0      0      0      0      0      0
# Very Good      0      0      0      0      2      1      1      0      0
#
# price      342    ...  18787  18788  18791  18795  18797  18803  18804  18806  \
# cut               ...
# Fair           0  ...      0      0      0      0      0      0      0      0
# Good           0  ...      0      1      0      0      0      0      0      0
# Ideal          0  ...      1      0      1      0      0      0      1      1
# Premium        1  ...      0      0      1      2      1      0      0      0
# Very Good      0  ...      0      0      0      0      0      1      0      0
#
# price      18818  18823
# cut
# Fair           0      0
# Good           0      0
# Ideal          0      0
# Premium        0      1
# Very Good      1      0
#
# [5 rows x 11602 columns]

# %% [markdown]
# 36. Write a Pandas program to calculate various summary statistics of carat series of diamonds DataFrame

# %%
df[['carat']].describe()
# Out:
#               carat
# count  53940.000000
# mean       0.797940
# std        0.474011
# min        0.200000
# 25%        0.400000
# 50%        0.700000
# 75%        1.040000
# max        5.010000

# %%
df.carat.describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %% [markdown]
# 37. Write a Pandas program to create a histogram of the 'carat' Series (distribution of a numerical variable) of diamonds DataFrame.

# %%
df.carat.plot(kind='hist')

# %% [markdown]
# 38. Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut' series of diamonds DataFrame

# %%
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df.cut.value_counts().plot(kind='bar')

# %% [markdown]
# 39. Write a Pandas program to create a DataFrame of booleans (True if missing, False if not missing) from diamonds DataFrame.

# %%
df.isnull().head()
# Out:
#    carat    cut  color  clarity  depth  table  price      x      y      z  \
# 0  False  False  False    False  False  False  False  False  False  False
# 1  False  False  False    False  False  False  False  False  False  False
# 2  False  False  False    False  False  False  False  False  False  False
# 3  False  False  False    False  False  False  False  False  False  False
# 4  False  False  False    False  False  False  False  False  False  False
#
#    Quality-Color    w>3
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False

# %% [markdown]
# 40. Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
df.isnull().sum()
# Out:
# carat            0
# cut              0
# color            0
# clarity          0
# depth            0
# table            0
# price            0
# x                0
# y                0
# z                0
# Quality-Color    0
# w>3              0
# dtype: int64

# %% [markdown]
# 41. Write a Pandas program to check the number of rows and columns and drop those row if 'any' values are missing in a row of diamonds DataFrame.

# %%
df.shape
# Out:
# (53940, 12)

# %%
print("After droping those rows where values are missing:")
df.dropna().shape
# Out:
# After droping those rows where values are missing:
# (53940, 12)

# %% [markdown]
# 42. Write a Pandas program to drop a row if any or all values in a row are missing of diamonds DataFrame on two specific columns.

# %%
print("\nAfter droping those rows where any value in a row is missing in carat and cut columns:")
print(df.dropna(subset=['carat', 'cut'], how='any').shape)
print("\nAfter droping those rows where all values in a row are missing in carat and cut columns:")
print(df.dropna(subset=['carat', 'cut'], how='all').shape)
# Out:
# After droping those rows where any value in a row is missing in carat and cut columns:
# (53940, 12)
#
# After droping those rows where all values in a row are missing in carat and cut columns:
# (53940, 12)

# %% [markdown]
# 43. Write a Pandas program to set an existing column as the index of diamonds DataFrame.

# %%
df.head()
# Out:
#        carat      cut clarity  depth  table  price     x     y     z
# color
# E       0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.set_index('color')#if make inplace =true it will chage Dfpermently
# Out:
#        carat        cut clarity  depth  table  price     x     y     z
# color
# E       0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...     ...    ...    ...    ...   ...   ...   ...
# D       0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# D       0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# D       0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# H       0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# D       0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %% [markdown]
# 44. Write a Pandas program to set an existing column as the index of diamonds DataFrame and restore the index name, and move the index back to a column.

# %%
df
# Out:
#        carat        cut clarity  depth  table  price     x     y     z
# color
# E       0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...     ...    ...    ...    ...   ...   ...   ...
# D       0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# D       0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# D       0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# H       0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# D       0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
print("\nNew Dataframe:")
df.set_index('color', inplace=True)
print(df.head())
print("\nNow restore the index name:")
df.index.name = 'color'
df.reset_index(inplace=True)
print(df.head())
# Out:
# New Dataframe:
#        carat      cut clarity  depth  table  price     x     y     z
# color
# E       0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75
#
# Now restore the index name:
#   color  carat      cut clarity  depth  table  price     x     y     z
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df
# Out:
#       color  carat        cut clarity  depth  table  price     x     y     z
# 0         E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1         E   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2         E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3         I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4         J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 53935     D   0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936     D   0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937     D   0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938     H   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939     D   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# 45. Write a Pandas program to access a specified Series index and the Series values of diamonds DataFrame.

# %%
df.head(2)
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31

# %%
df.color.value_counts().index
# Out:
# Index(['G', 'E', 'F', 'H', 'D', 'I', 'J'], dtype='object')

# %%
df.color.value_counts().values
# Out:
# array([11292,  9797,  9542,  8304,  6775,  5422,  2808], dtype=int64)

# %% [markdown]
# 46. Write a Pandas program to sort a Series by its values and index of diamonds DataFrame.

# %%
df.color.value_counts().sort_values()
# Out:
# J     2808
# I     5422
# D     6775
# H     8304
# F     9542
# E     9797
# G    11292
# Name: color, dtype: int64

# %%
df.color.value_counts().sort_index()
# Out:
# D     6775
# E     9797
# F     9542
# G    11292
# H     8304
# I     5422
# J     2808
# Name: color, dtype: int64

# %% [markdown]
# 47. Write a Pandas program to calculate the multiply of length, width and depth for each cut of diamonds DataFrame

# %%
print((df.x*df.y*df.z).head(10))
# Out:
# 0    38.202030
# 1    34.505856
# 2    38.076885
# 3    46.724580
# 4    51.917250
# 5    38.693952
# 6    38.830870
# 7    42.321081
# 8    36.425214
# 9    38.718000
# dtype: float64

# %% [markdown]
# 48. Write a Pandas program to concatenate the diamonds DataFrame with the 'color' Series.

# %%
df.head()
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.color
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
pd.concat([df,df.color],axis=1).head()
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z color
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43     E
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31     E
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31     E
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63     I
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75     J

# %% [markdown]
# 49. Write a Pandas program to read specified rows and all columns of diamonds DataFrame.

# %%
df.loc[0,:]
# Out:
# color          E
# carat       0.23
# cut        Ideal
# clarity      SI2
# depth       61.5
# table         55
# price        326
# x           3.95
# y           3.98
# z           2.43
# Name: 0, dtype: object

# %% [markdown]
# 50.Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds DataFrame.

# %%
df.loc[[0,5,7],:]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z
# 0     E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7     H   0.26  Very Good     SI1   61.9   55.0    337  4.07  4.11  2.53

# %% [markdown]
# 51. Write a Pandas program to read rows 2 through 5 and all columns of diamonds DataFrame.

# %%
df.loc[2:5,:]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z
# 2     E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48

# %% [markdown]
# 52. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' and 'price' of diamonds DataFrame.

# %%
df.loc[0:2,['color','price']].head()
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# 53. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' through 'price' (inclusive) of diamonds DataFrame

# %%
df.loc[0:2,'color':'price']
# Out:
#   color  carat      cut clarity  depth  table  price
# 0     E   0.23    Ideal     SI2   61.5   55.0    326
# 1     E   0.21  Premium     SI1   59.8   61.0    326
# 2     E   0.23     Good     VS1   56.9   65.0    327

# %% [markdown]
# 54. Write a Pandas program to read rows in which the 'cut' is 'Premium', column 'color' of diamonds DataFrame.

# %%
df.loc[df.cut=='Premium','color']
# Out:
# 1        E
# 3        I
# 12       F
# 14       E
# 15       E
#         ..
# 53928    E
# 53930    E
# 53931    F
# 53934    D
# 53938    H
# Name: color, Length: 13791, dtype: object

# %% [markdown]
# 55. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
df.iloc[[0,1],[0,3]]
# Out:
#   color clarity
# 0     E     SI2
# 1     E     SI1

# %% [markdown]
# 56. Write a Pandas program to read rows in positions 0 through 4, columns in positions 1 through 4 of diamonds DataFrame.

# %%
df.iloc[0:4,1:4]
# Out:
#    carat      cut clarity
# 0   0.23    Ideal     SI2
# 1   0.21  Premium     SI1
# 2   0.23     Good     VS1
# 3   0.29  Premium     VS2

# %% [markdown]
# 57. Write a Pandas program to read rows in positions 0 through 4 (exclusive) and all columns of diamonds DataFrame.

# %%
df.iloc[0:5,:]
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# 58. Write a Pandas program to read rows 2 through 5 (inclusive), columns in positions 0 through 2 (exclusive) of diamonds DataFrame.

# %%
df.iloc[2:5,0:2]
# Out:
#   color  carat
# 2     E   0.23
# 3     I   0.29
# 4     J   0.31

# %% [markdown]
# 59. Write a Pandas program to print a concise summary of diamonds DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   color    53940 non-null  object
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# 60. Write a Pandas program to get the true memory usage by diamonds DataFrame.

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   color    53940 non-null  object
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 12.4 MB

# %% [markdown]
# 62. Write a Pandas program to get randomly sample rows from diamonds DataFrame

# %%
df.sample(n=3)
# Out:
#       color  carat    cut clarity  depth  table  price     x     y     z
# 19270     G   1.21  Ideal     VS2   61.1   57.0   7996  6.95  6.85  4.22
# 40174     G   0.55  Ideal     SI2   62.1   56.0   1117  5.25  5.22  3.25
# 49692     I   0.71   Good     VS2   61.1   60.6   2145  5.71  5.74  3.49

# %% [markdown]
# 64.Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.

# %%
print("\nSample 75% of diamonds DataFrame's rows without replacement:")
result = df.sample(frac=0.75, random_state=99)
print(result)
print("\nRemaining 25% of the rows:")
print(df.loc[df.index.isin(result.index), :])
# Out:
# Sample 75% of diamonds DataFrame's rows without replacement:
#       color  carat        cut clarity  depth  table  price     x     y     z
# 42653     G   0.40    Premium      IF   60.8   58.0   1333  4.73  4.77  2.89
# 4069      D   0.31  Very Good     SI1   63.0   55.0    571  4.32  4.34  2.73
# 27580     F   1.60      Ideal     VS2   62.0   55.0  18421  7.49  7.54  4.66
# 33605     D   0.31       Good     SI2   63.1   54.0    462  4.33  4.38  2.75
# 34415     G   0.30      Ideal      IF   61.2   57.0    863  4.35  4.38  2.67
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 4677      F   1.05    Premium     SI2   61.1   59.0   3672  6.54  6.61  4.02
# 34855     G   0.30       Good    VVS2   63.8   56.0    878  4.29  4.27  2.73
# 13929     I   2.00       Fair      I1   66.0   60.0   5667  7.78  7.74  5.10
# 31091     G   0.33  Very Good    VVS2   62.8   57.0    752  4.39  4.47  2.78
# 41428     E   0.53  Very Good     SI2   63.2   54.0   1227  5.19  5.16  3.27
#
# [40455 rows x 10 columns]
#
# Remaining 25% of the rows:
#       color  carat        cut clarity  depth  table  price     x     y     z
# 0         E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1         E   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2         E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3         I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4         J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 53933     E   0.70  Very Good     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53936     D   0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937     D   0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938     H   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939     D   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [40455 rows x 10 columns]

# %% [markdown]
# Write a Pandas program to read the diamonds DataFrame and detect duplicate color.

# %%
print("\nCount the duplicate items:")
print(df.clarity.duplicated().sum())
# Out:
# Count the duplicate items:
# 53932

# %% [markdown]
# Write a Pandas program to count the duplicate rows of diamonds DataFrame.

# %%
df.duplicated().sum()
# Out:
# 146
